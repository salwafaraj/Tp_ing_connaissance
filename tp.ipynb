# %% [markdown]
# # <p style="background-color:#c3c3e6;font-family:newtimeroman;color:#09095e;font-size:150%;text-align:center;border-radius:10px 10px;">♦  Tp : 2  ♦ </p>

# %% [markdown]
# <div>
#     <h2 style="color:#09095e ;text-align: left;"><span style="letter-spacing: 2px;">Réalisé par :</span></h2>
#
# </div>

# %% [markdown]
# <div style="text-align: left;">
#     <b><li>Salwa Faraj</li></b>
#
#
#
# </div>

# %% [markdown]
# # 1ère Partie : Préparation de l’environnement et création du réseau

# %%
pip install spacy networkx matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: spacy in c:\users\salwa\appdata\roaming\python\python312\site-packages (3.8.2)
# Requirement already satisfied: networkx in c:\users\salwa\appdata\roaming\python\python312\site-packages (3.2.1)
# Requirement already satisfied: matplotlib in c:\users\salwa\appdata\roaming\python\python312\site-packages (3.9.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.0 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from spacy) (8.3.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from spacy) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from spacy) (4.66.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in c:\users\salwa\appdata\roaming\python\python312\site-packages (from spacy) (69.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from spacy) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from spacy) (2.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: language-data>=1.2 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.9.0)
# Requirement already satisfied: six>=1.5 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<1.1.0,>=1.0.0 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from thinc<8.4.0,>=8.3.0->spacy) (1.0.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from thinc<8.4.0,>=8.3.0->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\salwa\appdata\roaming\python\python312\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in c:\users\salwa\appdata\roaming\python\python312\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\salwa\appdata\roaming\python\python312\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy
import networkx as nx
import matplotlib.pyplot as plt
from itertools import combinations

# %%
# Charger le modèle de spaCy
nlp = spacy.load("en_core_web_sm")

# Exemple de texte simple
text = """
Artificial intelligence and machine learning are closely related fields.
Deep learning is a subset of machine learning that uses neural networks.
Natural language processing is a key application of artificial intelligence.
"""


doc = nlp(text)

# %%
entities = []  # Initialize the entities list
relations = []  # Initialize the relations list

for sentence in doc.sents:
    # On inclut à la fois les entités nommées et les groupes nominaux importants
    ents_in_sentence = []

    # Ajout des entités nommées
    for ent in sentence.ents:
        ents_in_sentence.append(ent.text)

    # Ajout des groupes nominaux importants
    for chunk in sentence.noun_chunks:
        if not any(ent == chunk.text for ent in ents_in_sentence):
            if len(chunk.text.split()) > 1:  # On garde les groupes de mots
                ents_in_sentence.append(chunk.text)

    entities.extend(ents_in_sentence)

    # Création des relations par co-occurrence
    for ent1, ent2 in combinations(ents_in_sentence, 2):
        relations.append((ent1, ent2))

# Suppression des doublons
entities = list(set(entities))
relations = list(set(relations))

# Affichage des entités et relations extraites
print("\nEntités extraites:")
for e in entities:
    print(f"- {e}")

print("\nRelations extraites:")
for r in relations:
    print(f"- {r[0]} <--> {r[1]}")
# Out:
# Entités extraites:
# - a subset
# - closely related fields
# - a key application
# - Deep learning
# - machine learning
# - neural networks
# - artificial intelligence
# - Natural language processing
# -
# Artificial intelligence
#
# Relations extraites:
# - machine learning <--> closely related fields
# - a subset <--> machine learning
# - Natural language processing <--> a key application
# - Natural language processing <--> artificial intelligence
# - Deep learning <--> neural networks
# - a key application <--> artificial intelligence
# - Deep learning <--> machine learning
# - Deep learning <--> a subset
# - machine learning <--> neural networks
# - a subset <--> neural networks
# -
# Artificial intelligence <--> closely related fields
# -
# Artificial intelligence <--> machine learning

# %%
# 5. Création du graphe sémantique
G = nx.Graph()
G.add_nodes_from(entities)
G.add_edges_from(relations)

# 6. Analyse et visualisation du réseau
# Calcul des métriques de centralité
degree_centrality = nx.degree_centrality(G)
betweenness_centrality = nx.betweenness_centrality(G)
closeness_centrality = nx.closeness_centrality(G)

print("\nAnalyse du réseau:")
print(f"Nombre de nœuds: {G.number_of_nodes()}")
print(f"Nombre d'arêtes: {G.number_of_edges()}")
print(f"Densité du réseau: {nx.density(G):.3f}")
# Out:
# Analyse du réseau:
# Nombre de nœuds: 9
# Nombre d'arêtes: 12
# Densité du réseau: 0.333

# %%
# Visualisation du réseau
plt.figure(figsize=(12, 8))
pos = nx.spring_layout(G, k=1, iterations=50)

# Taille des nœuds basée sur leur centralité
node_sizes = [v * 3000 for v in degree_centrality.values()]

# Dessin du graphe
nx.draw(G, pos,
        node_color='lightblue',
        node_size=node_sizes,
        edge_color='gray',
        alpha=0.6,
        with_labels=True,
        font_size=8,
        font_weight='bold')

plt.title("Réseau Sémantique du Texte")
plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\salwa\AppData\Local\Temp\ipykernel_75456\3341341346.py:20: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# <h2 style=" color:#428d8e;">2
# ème Partie : Exploitation avancée du réseau</h2>

# %% [markdown]
# 1. Utiliser un corpus plus large pour voir comment le réseau évolue.

# %%
# Charger un modèle de langue
nlp = spacy.load('en_core_web_sm')

# Appliquer le modèle à un texte plus long (ex. un article Wikipedia)
text = """
Albert Einstein is known for his theory of relativity, which transformed the understanding of space and time. Albert Einstein worked at prestigious institutions, including the University of Berlin and the Institute for Advanced Study in Princeton, New Jersey. He received the Nobel Prize in Physics for his work on the photoelectric effect. His contributions have greatly influenced the fields of physics, mathematics, and philosophy.
"""
# Traitement du texte
doc = nlp(text)

# Extraire les entités nommées
entities = [ent.text for ent in doc.ents]

# Créer un réseau de relations entre les entités
relations = [(ent1, ent2) for ent1 in entities for ent2 in entities if ent1 != ent2]

print("Entités extraites :", entities)
print("Relations extraites :", relations)
# Out:
# Entités extraites : ['Albert Einstein', 'Albert Einstein', 'the University of Berlin', 'the Institute for Advanced Study', 'Princeton', 'New Jersey', 'the Nobel Prize in Physics']
# Relations extraites : [('Albert Einstein', 'the University of Berlin'), ('Albert Einstein', 'the Institute for Advanced Study'), ('Albert Einstein', 'Princeton'), ('Albert Einstein', 'New Jersey'), ('Albert Einstein', 'the Nobel Prize in Physics'), ('Albert Einstein', 'the University of Berlin'), ('Albert Einstein', 'the Institute for Advanced Study'), ('Albert Einstein', 'Princeton'), ('Albert Einstein', 'New Jersey'), ('Albert Einstein', 'the Nobel Prize in Physics'), ('the University of Berlin', 'Albert Einstein'), ('the University of Berlin', 'Albert Einstein'), ('the University of Berlin', 'the Institute for Advanced Study'), ('the University of Berlin', 'Princeton'), ('the University of Berlin', 'New Jersey'), ('the University of Berlin', 'the Nobel Prize in Physics'), ('the Institute for Advanced Study', 'Albert Einstein'), ('the Institute for Advanced Study', 'Albert Einstein'), ('the Institute for Advanced Study', 'the University of Berlin'), ('the Institute for Advanced Study', 'Princeton'), ('the Institute for Advanced Study', 'New Jersey'), ('the Institute for Advanced Study', 'the Nobel Prize in Physics'), ('Princeton', 'Albert Einstein'), ('Princeton', 'Albert Einstein'), ('Princeton', 'the University of Berlin'), ('Princeton', 'the Institute for Advanced Study'), ('Princeton', 'New Jersey'), ('Princeton', 'the Nobel Prize in Physics'), ('New Jersey', 'Albert Einstein'), ('New Jersey', 'Albert Einstein'), ('New Jersey', 'the University of Berlin'), ('New Jersey', 'the Institute for Advanced Study'), ('New Jersey', 'Princeton'), ('New Jersey', 'the Nobel Prize in Physics'), ('the Nobel Prize in Physics', 'Albert Einstein'), ('the Nobel Prize in Physics', 'Albert Einstein'), ('the Nobel Prize in Physics', 'the University of Berlin'), ('the Nobel Prize in Physics', 'the Institute for Advanced Study'), ('the Nobel Prize in Physics', 'Princeton'), ('the Nobel Prize in Physics', 'New Jersey')]

# %% [markdown]
# 2.Explorer des méthodes avancées de détection de relations, telles que les dépendances
# syntaxiques.

# %%
for token in doc:
    # Identifier les relations sujet-verbe-objet
    if token.dep_ == "nsubj" and token.head.pos_ == "VERB":
        subj = token.text
        verb = token.head.text
        # Vérifier s'il y a un objet associé
        for child in token.head.children:
            if child.dep_ == "dobj":
                obj = child.text
                relations.append((subj, verb, obj))
    
    # Identifier les relations attributives
    if token.dep_ == "attr" and token.head.pos_ == "VERB":
        subject = [child.text for child in token.head.lefts if child.dep_ == "nsubj"]
        if subject:
            relations.append((subject[0], token.head.text, token.text))
    
    # Capturer les adjectifs pour les descriptions
    if token.dep_ == "amod":
        relations.append((token.head.text, "has_property", token.text))

# Afficher les relations extraites
print("Relations extraites :", relations)
# Out:
# Relations extraites : [('Albert Einstein', 'the University of Berlin'), ('Albert Einstein', 'the Institute for Advanced Study'), ('Albert Einstein', 'Princeton'), ('Albert Einstein', 'New Jersey'), ('Albert Einstein', 'the Nobel Prize in Physics'), ('Albert Einstein', 'the University of Berlin'), ('Albert Einstein', 'the Institute for Advanced Study'), ('Albert Einstein', 'Princeton'), ('Albert Einstein', 'New Jersey'), ('Albert Einstein', 'the Nobel Prize in Physics'), ('the University of Berlin', 'Albert Einstein'), ('the University of Berlin', 'Albert Einstein'), ('the University of Berlin', 'the Institute for Advanced Study'), ('the University of Berlin', 'Princeton'), ('the University of Berlin', 'New Jersey'), ('the University of Berlin', 'the Nobel Prize in Physics'), ('the Institute for Advanced Study', 'Albert Einstein'), ('the Institute for Advanced Study', 'Albert Einstein'), ('the Institute for Advanced Study', 'the University of Berlin'), ('the Institute for Advanced Study', 'Princeton'), ('the Institute for Advanced Study', 'New Jersey'), ('the Institute for Advanced Study', 'the Nobel Prize in Physics'), ('Princeton', 'Albert Einstein'), ('Princeton', 'Albert Einstein'), ('Princeton', 'the University of Berlin'), ('Princeton', 'the Institute for Advanced Study'), ('Princeton', 'New Jersey'), ('Princeton', 'the Nobel Prize in Physics'), ('New Jersey', 'Albert Einstein'), ('New Jersey', 'Albert Einstein'), ('New Jersey', 'the University of Berlin'), ('New Jersey', 'the Institute for Advanced Study'), ('New Jersey', 'Princeton'), ('New Jersey', 'the Nobel Prize in Physics'), ('the Nobel Prize in Physics', 'Albert Einstein'), ('the Nobel Prize in Physics', 'Albert Einstein'), ('the Nobel Prize in Physics', 'the University of Berlin'), ('the Nobel Prize in Physics', 'the Institute for Advanced Study'), ('the Nobel Prize in Physics', 'Princeton'), ('the Nobel Prize in Physics', 'New Jersey'), ('which', 'transformed', 'understanding'), ('institutions', 'has_property', 'prestigious'), ('He', 'received', 'Prize'), ('effect', 'has_property', 'photoelectric'), ('contributions', 'influenced', 'fields')]

# %% [markdown]
# 3.Appliquer une mesure de similarité pour connecter les concepts liés sémantiquement
# mais non explicitement co-mentionnés.

# %%
# Extraire les entités nommées
entities = list(set([ent.text for ent in doc.ents]))

# Calculer les similarités entre toutes les paires d'entités
similarity_threshold = 0.7  # Seuil de similarité
similarity_relations = []

for ent1, ent2 in combinations(entities, 2):
    ent1_nlp = nlp(ent1)
    ent2_nlp = nlp(ent2)
    
    # Calculer la similarité cosinus entre les vecteurs des entités
    similarity = ent1_nlp.similarity(ent2_nlp)
    
    # Vérifier si la similarité dépasse le seuil
    if similarity >= similarity_threshold:
        similarity_relations.append((ent1, "similar_to", ent2, similarity))
# Filtrer les relations similaires pour éviter les doublons
filtered_relations = []
seen_pairs = set()

for src, rel, tgt, weight in similarity_relations:
    if (src, tgt) not in seen_pairs and (tgt, src) not in seen_pairs:
        filtered_relations.append((src, rel, tgt, weight))  # Garder également le poids (similarité)
        seen_pairs.add((src, tgt))
        # Afficher la similarité calculée
        print(f"{src} - {rel} -> {tgt} (similarité: {weight:.2f})")

        # Préparer les éléments pour le graphique (nœuds et arêtes)
nodes = [{"data": {"id": concept, "label": concept}} for concept in entities]

# Créer les arêtes avec les relations filtrées, sans modification de poids
edges = [{"data": {"source": src, "target": tgt}} for src, _, tgt, _ in filtered_relations]
# Out:
# Albert Einstein - similar_to -> New Jersey (similarité: 0.77)
# the University of Berlin - similar_to -> the Institute for Advanced Study (similarité: 0.72)
# the Institute for Advanced Study - similar_to -> the Nobel Prize in Physics (similarité: 0.84)
# C:\Users\salwa\AppData\Local\Temp\ipykernel_1192\811911724.py:13: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   similarity = ent1_nlp.similarity(ent2_nlp)

# %% [markdown]
# 4.Créer une interface graphique qui permet de naviguer à travers le réseau sémantique et
# de visualiser les relations entre les concepts.
# Utilisation de librairies de visualisation de graphes comme D3.js, Cytoscape.js ou
# Graphviz

# %%
# Lancer l'application Dash
app = dash.Dash(__name__)

# Définir la mise en page de l'application
app.layout = html.Div([
    cyto.Cytoscape(
        id='cytoscape-layout',
        elements=nodes + edges,
        layout={'name': 'circle'},  # Disposition simple en cercle
        style={'width': '100%', 'height': '600px'},
        stylesheet=[
            {'selector': 'node', 
             'style': {'content': 'data(label)', 'background-color': '#0074D9', 'color': '#fff', 'text-valign': 'center', 'text-halign': 'center'}},  # Style des nœuds
            {'selector': 'edge', 
             'style': {'line-color': '#7FDBFF', 'width': 2}}  # Style des arêtes
        ]
    )
])

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
